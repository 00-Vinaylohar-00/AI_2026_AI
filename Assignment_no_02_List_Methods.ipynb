# %% [markdown]
# <a href="https://colab.research.google.com/github/00-Vinaylohar-00/AI_2026_AI/blob/main/Assignment_no_02_List_Methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
c=[]
c
# Out:
# []

# %%
c.append('sai')
c
# Out:
# ['sai']

# %%
c.clear()
c
# Out:
# []

# %%
c.append([20,500,60,90,70])
c
# Out:
# [[20, 500, 60, 90, 70]]

# %%
c.append('sai')
c
# Out:
# [[20, 500, 60, 90, 70], 'sai']

# %%
c.append("tea")
c
# Out:
# [[20, 500, 60, 90, 70], 'sai', 'tea']

# %%
c.extend(["sachin","ramesh","suresh"])
c
# Out:
# [[20, 500, 60, 90, 70], 'sai', 'tea', 'sachin', 'ramesh', 'suresh']

# %%
c.extend([40,30,12,65,45])
c
# Out:
# [[20, 500, 60, 90, 70],
#  'sai',
#  'tea',
#  'sachin',
#  'ramesh',
#  'suresh',
#  40,
#  30,
#  12,
#  65,
#  45]

# %%
c.pop()
c
# Out:
# [[20, 500, 60, 90, 70],
#  'sai',
#  'tea',
#  'sachin',
#  'ramesh',
#  'suresh',
#  40,
#  30,
#  12,
#  65]

# %%
c.pop(6)
c
# Out:
# [[20, 500, 60, 90, 70], 'sai', 'tea', 'sachin', 'ramesh', 'suresh', 30, 12, 65]

# %%
c.count('sachin')
# Out:
# 1

# %%
a=[]
a = c.copy()
a
# Shallow copy (different IDs)
# Out:
# [[20, 500, 60, 90, 70], 'sai', 'tea', 'sachin', 'ramesh', 'suresh', 30, 12, 65]

# %%
a.append("vinay")
a
# Out:
# [[20, 500, 60, 90, 70],
#  'sai',
#  'tea',
#  'sachin',
#  'ramesh',
#  'suresh',
#  30,
#  12,
#  65,
#  'vinay']

# %%
c
# Out:
# [[20, 500, 60, 90, 70], 'sai', 'tea', 'sachin', 'ramesh', 'suresh', 30, 12, 65]

# %%
d=c
d
# Deep copy (Same IDs)
# Out:
# [[20, 500, 60, 90, 70], 'sai', 'tea', 'sachin', 'ramesh', 'suresh', 30, 12, 65]

# %%
c
# Out:
# [[20, 500, 60, 90, 70], 'sai', 'tea', 'sachin', 'ramesh', 'suresh', 30, 12, 65]

# %%
c.insert(-1,55)
c
# Out:
# [[20, 500, 60, 90, 70],
#  'sai',
#  'tea',
#  'sachin',
#  'ramesh',
#  'suresh',
#  30,
#  12,
#  65,
#  -1,
#  55,
#  -1]

# %%
c.insert(2,'cow')
c
# Insert method takes two arguments first one as index and another one as the data we want to add to list at given index
# Out:
# [[20, 500, 60, 90, 70],
#  'sai',
#  'cow',
#  'tea',
#  'sachin',
#  'ramesh',
#  'suresh',
#  30,
#  12,
#  65,
#  -1,
#  55,
#  -1]

# %%
c.index('ramesh')
# Out:
# 5

# %%
c.index(30)
# Out:
# 7

# %%
c.remove(-1)
c
# Out:
# [[20, 500, 60, 90, 70],
#  'sai',
#  'cow',
#  'tea',
#  'sachin',
#  'ramesh',
#  'suresh',
#  30,
#  12,
#  65,
#  55]

# %%
c.remove('suresh')
c
# Out:
# [[20, 500, 60, 90, 70],
#  'sai',
#  'cow',
#  'tea',
#  'sachin',
#  'ramesh',
#  30,
#  12,
#  65,
#  55]

# %%
c.reverse()
c
# Out:
# [55,
#  65,
#  12,
#  30,
#  'ramesh',
#  'sachin',
#  'tea',
#  'cow',
#  'sai',
#  [20, 500, 60, 90, 70]]

# %%
a=[1,2,3,5,6,7,8,9,10,54,2,4,85,72,7,4,86,54,89]
a.sort()
a
# Out:
# [1, 2, 2, 3, 4, 4, 5, 6, 7, 7, 8, 9, 10, 54, 54, 72, 85, 86, 89]

# %%
a.sort()
a[-5]
# Out:
# 54

# %%
a.sort(reverse=True)
a
# Out:
# [89, 86, 85, 72, 54, 54, 10, 9, 8, 7, 7, 6, 5, 4, 4, 3, 2, 2, 1]
