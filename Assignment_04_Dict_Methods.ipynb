# %% [markdown]
# <a href="https://colab.research.google.com/github/00-Vinaylohar-00/AI_2026_AI/blob/main/Assignment_04_Dict_Methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s={'name':'vamshi','city':'hydrabad','age':24,}
s.clear()
s
# Out:
# {}

# %%
s={'name':'vamshi','city':'hydrabad','age':24,}
t={}
t=s.copy()
t
# Out:
# {'name': 'vamshi', 'city': 'hydrabad', 'age': 24}

# %%
p={1,2,3,4,5}
q={'ram','vishal','shyam'}
r=dict.fromkeys(p,q)
r
# dict.fromkeys() function creates the dictonary on given p and q sets as it takes first set as keys and second set as values
# Out:
# {1: {'ram', 'shyam', 'vishal'},
#  2: {'ram', 'shyam', 'vishal'},
#  3: {'ram', 'shyam', 'vishal'},
#  4: {'ram', 'shyam', 'vishal'},
#  5: {'ram', 'shyam', 'vishal'}}

# %%
s
# Out:
# {'name': 'vamshi', 'city': 'hydrabad', 'age': 24}

# %%
s.get('age')
#fetch the data drom dict
# Out:
# 24

# %%
s.items()
# returns items in dict
# Out:
# dict_items([('name', 'vamshi'), ('city', 'hydrabad'), ('age', 24)])

# %%
s.keys()
# fetch the keys in dict
# Out:
# dict_keys(['name', 'city', 'age'])

# %%
s.pop('age')
# removes the key=pair from the dict
# Out:
# 24

# %%
s
# Out:
# {'name': 'vamshi', 'city': 'hydrabad'}

# %%
s.popitem()
# removes last paired item and key value
# Out:
# ('city', 'hydrabad')

# %%
s
# Out:
# {'name': 'vamshi'}

# %%
s.setdefault(5)
s
# Out:
# {'name': 'vamshi', 5: None}

# %%
s.setdefault('age',25)
s
# adds the key value pairs to the dict , if no value is given means it will gives value as None
# Out:
# {'name': 'vamshi', 5: None, 'age': 25}

# %%
s.update({'name':'prudhvee'})
s
# important while using update function is always use curly bracket while given any change in dict
# Out:
# {'name': 'prudhvee', 5: None, 'age': 25}

# %%
s.values()
# returns the values from the dict
# Out:
# dict_values(['prudhvee', None, 25])
